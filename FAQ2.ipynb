# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanish-ops7710/DAFA1/blob/main/FAQ2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.listdir('/content')
# Out:
# ['.config',
#  'patients-leaving-california-hospitals-against-medical-advice.csv',
#  'sample_data']

# %%
df = pd.read_csv('/content/patients-leaving-california-hospitals-against-medical-advice.csv')

# %%
df.head()
# Out:
#          Category  Subcategory  Year  All Discharges  Total Dis Category  \
# 0  Admission Type     Elective  2019          524882             2709060
# 1  Admission Type    Emergency  2019         1173202             2709060
# 2  Admission Type       Urgent  2019         1010976             2709060
# 3             Age  18-39 Years  2019          679695             2747558
# 4             Age  40-64 Years  2019          876807             2747558
#
#    AMA Discharges  Total AMA Dis Category  AMA Discharges More Than Once  \
# 0            4841                   64827                           1188
# 1           37360                   64827                          12790
# 2           22626                   64827                           6597
# 3           20918                   65704                           6579
# 4           31111                   65704                          10806
#
#    Total AMA Dis >1x Category  Percent of Total Discharges  \
# ...

# %%
df.columns
# Out:
# Index(['Category', 'Subcategory', 'Year', 'All Discharges',
#        'Total Dis Category', 'AMA Discharges', 'Total AMA Dis Category',
#        'AMA Discharges More Than Once', 'Total AMA Dis >1x Category',
#        'Percent of Total Discharges', 'Percent of AMA Discharges',
#        'Percent of AMA Discharges >1x'],
#       dtype='object')

# %%
df.info()

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       203 non-null    object
#  1   Subcategory                    203 non-null    object
#  2   Year                           203 non-null    object
#  3   All Discharges                 203 non-null    int64
#  4   Total Dis Category             203 non-null    int64
#  5   AMA Discharges                 203 non-null    int64
#  6   Total AMA Dis Category         203 non-null    int64
#  7   AMA Discharges More Than Once  203 non-null    int64
#  8   Total AMA Dis >1x Category     203 non-null    int64
#  9   Percent of Total Discharges    203 non-null    float64
#  10  Percent of AMA Discharges      203 non-null    float64
#  11  Percent of AMA Discharges >1x  203 non-null    float64
# ...

# %%
df.describe()
# Out:
#        All Discharges  Total Dis Category  AMA Discharges  \
# count    2.030000e+02        2.030000e+02      203.000000
# mean     7.944337e+05        3.436429e+06    21834.906404
# std      1.442629e+06        3.505715e+06    39218.848570
# min      8.414000e+03        8.689620e+05      267.000000
# 25%      5.086800e+04        2.415746e+06     1829.500000
# 50%      2.473550e+05        2.496871e+06     7587.000000
# 75%      1.073545e+06        2.735185e+06    24462.500000
# max      1.219078e+07        1.274809e+07   284541.000000
#
#        Total AMA Dis Category  AMA Discharges More Than Once  \
# count              203.000000                     203.000000
# mean             94956.694581                    6888.068966
# std              95826.960134                   12560.704146
# min              23069.000000                      67.000000
# 25%              64827.000000                     454.500000
# 50%              70357.000000                    1956.000000
# ...

# %%
ama = df.groupby("Category")["AMA Discharges"].sum().sort_values(ascending=False)

ama
# Out:
# Category
# Age                      698318
# Assigned Sex at Birth    698272
# Expected Payer           698116
# Homeless Status          696674
# Race/Ethnicity Group     694434
# Admission Type           685208
# Primary Diagnosis        261464
# Name: AMA Discharges, dtype: int64

# %%
import matplotlib.pyplot as plt

ama.plot(kind="bar", figsize=(10,5))
plt.title("AMA Discharges by Category")
plt.xlabel("Category")
plt.ylabel("AMA Discharges")
plt.xticks(rotation=45)
plt.show()
